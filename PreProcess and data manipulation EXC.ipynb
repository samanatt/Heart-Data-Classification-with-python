# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Saman\Desktop\Heart data\Heart data.csv")
df
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral
# 0                   63    1           1           145.0         233.0  \
# 1                   37    1           3           130.0         250.0
# 2                   41    0           2           130.0         204.0
# 3                   56    1           2           120.0         236.0
# 4                   57    0           4           120.0         354.0
# ..                 ...  ...         ...             ...           ...
# 592                 52    1           4           140.0         266.0
# 593                 43    1           4           140.0         288.0
# 594                 41    1           4           120.0         336.0
# 595                 44    1           4           135.0         491.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced
# ...

# %% [markdown]
# # Data Frames Properties(Attributes)

# %%
df.dtypes
# Out:
# Age (age in year)          int64
# sex                        int64
# chest pain                 int64
# blood pressure           float64
# cholestoral              float64
# blood sugar              float64
# electrocardiographic     float64
# heart rate               float64
# exercise induced         float64
# depression               float64
# slope                    float64
# ca                       float64
# thal                     float64
# c                          int64
# dtype: object

# %%
df.size
# Out:
# 8358

# %%
df.shape
# Out:
# (597, 14)

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['Age (age in year)', 'sex', 'chest pain', 'blood pressure',
#        'cholestoral ', 'blood sugar', 'electrocardiographic ', 'heart rate',
#        'exercise induced', 'depression ', 'slope', 'ca', 'thal', 'c'],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=597, step=1),
#  Index(['Age (age in year)', 'sex', 'chest pain', 'blood pressure',
#         'cholestoral ', 'blood sugar', 'electrocardiographic ', 'heart rate',
#         'exercise induced', 'depression ', 'slope', 'ca', 'thal', 'c'],
#        dtype='object')]

# %%
df.values
# Out:
# array([[63.,  1.,  1., ...,  0.,  6.,  0.],
#        [37.,  1.,  3., ...,  0.,  3.,  0.],
#        [41.,  0.,  2., ...,  0.,  3.,  0.],
#        ...,
#        [41.,  1.,  4., ..., nan, nan,  1.],
#        [44.,  1.,  4., ..., nan, nan,  1.],
#        [49.,  1.,  4., ..., nan, nan,  1.]])

# %% [markdown]
# # Data Frames Method

# %%
df.head()
# Out:
#    Age (age in year)  sex  chest pain  blood pressure  cholestoral
# 0                 63    1           1           145.0         233.0  \
# 1                 37    1           3           130.0         250.0
# 2                 41    0           2           130.0         204.0
# 3                 56    1           2           120.0         236.0
# 4                 57    0           4           120.0         354.0
#
#    blood sugar  electrocardiographic   heart rate  exercise induced
# 0          1.0                    2.0       150.0               0.0  \
# 1          0.0                    0.0       187.0               0.0
# 2          0.0                    2.0       172.0               0.0
# 3          0.0                    0.0       178.0               0.0
# 4          0.0                    0.0       163.0               1.0
#
#    depression   slope   ca  thal  c
# 0          2.3    3.0  0.0   6.0  0
# 1          3.5    3.0  0.0   3.0  0
# ...

# %%
df.tail()
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral
# 592                 52    1           4           140.0         266.0  \
# 593                 43    1           4           140.0         288.0
# 594                 41    1           4           120.0         336.0
# 595                 44    1           4           135.0         491.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced
# 592          0.0                    0.0       134.0               1.0  \
# 593          0.0                    0.0       135.0               1.0
# 594          0.0                    0.0       118.0               1.0
# 595          0.0                    0.0       135.0               0.0
# 596          0.0                    0.0       122.0               0.0
#
#      depression   slope  ca  thal  c
# 592          2.0    2.0 NaN   NaN  1
# 593          2.0    2.0 NaN   NaN  1
# ...

# %%
df.describe().T
# Out:
#                        count        mean        std   min    25%    50%
# Age (age in year)      597.0   51.182580   9.074366  28.0   44.0   52.0  \
# sex                    597.0    0.701843   0.457833   0.0    0.0    1.0
# chest pain             597.0    3.072027   0.965776   1.0    2.0    3.0
# blood pressure         596.0  132.129195  17.603812  92.0  120.0  130.0
# cholestoral            574.0  248.655052  59.784805  85.0  211.0  242.5
# blood sugar            589.0    0.110357   0.313600   0.0    0.0    0.0
# electrocardiographic   596.0    0.610738   0.869358   0.0    0.0    0.0
# heart rate             596.0  144.456376  23.794282  71.0  128.0  146.0
# exercise induced       596.0    0.315436   0.465080   0.0    0.0    0.0
# depression             597.0    0.816248   1.067938   0.0    0.0    0.2
# slope                  407.0    1.675676   0.572758   1.0    1.0    2.0
# ca                     303.0    0.693069   1.049212   0.0    0.0    0.0
# ...

# %%
df.max()
# Out:
# Age (age in year)         77.0
# sex                        1.0
# chest pain                 4.0
# blood pressure           200.0
# cholestoral              603.0
# blood sugar                1.0
# electrocardiographic       2.0
# heart rate               202.0
# exercise induced           1.0
# depression                 6.2
# slope                      3.0
# ca                         9.0
# thal                       7.0
# c                          1.0
# dtype: float64

# %%
df.mean()
# Out:
# Age (age in year)         51.182580
# sex                        0.701843
# chest pain                 3.072027
# blood pressure           132.129195
# cholestoral              248.655052
# blood sugar                0.110357
# electrocardiographic       0.610738
# heart rate               144.456376
# exercise induced           0.315436
# depression                 0.816248
# slope                      1.675676
# ca                         0.693069
# thal                       4.811550
# c                          0.410385
# dtype: float64

# %%
df.sample()
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral
# 231                 48    0           4           120.0         254.0  \
#
#      blood sugar  electrocardiographic   heart rate  exercise induced
# 231          0.0                    1.0       110.0               0.0  \
#
#      depression   slope  ca  thal  c
# 231          0.0    NaN NaN   NaN  0

# %%
df2 = df
#df2 = df.copy()

# %%
df2.dropna()
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral
# 0                   63    1           1           145.0         233.0  \
# 1                   37    1           3           130.0         250.0
# 2                   41    0           2           130.0         204.0
# 3                   56    1           2           120.0         236.0
# 4                   57    0           4           120.0         354.0
# ..                 ...  ...         ...             ...           ...
# 577                 77    1           4           125.0         304.0
# 578                 64    1           4           145.0         212.0
# 579                 38    1           1           120.0         231.0
# 580                 61    1           4           138.0         166.0
# 581                 58    1           4           114.0         318.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced
# ...

# %%
#the mean values of the first 50 records
df.head(50).mean()
# Out:
# Age (age in year)         52.960000
# sex                        0.600000
# chest pain                 2.720000
# blood pressure           134.940000
# cholestoral              248.220000
# blood sugar                0.160000
# electrocardiographic       0.880000
# heart rate               158.620000
# exercise induced           0.160000
# depression                 0.896000
# slope                      1.420000
# ca                         0.180000
# thal                       3.612245
# c                          0.000000
# dtype: float64

# %%
df['sex']
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 592    1
# 593    1
# 594    1
# 595    1
# 596    1
# Name: sex, Length: 597, dtype: int64

# %% [markdown]
# # Data Frames GroupBy method

# %%
df_sex = df.groupby(['sex']).mean()
df_sex
# Out:
#      Age (age in year)  chest pain  blood pressure  cholestoral   blood sugar
# sex
# 0            52.050562    2.893258      131.841808    255.660819     0.091954  \
# 1            50.813842    3.147971      132.250597    245.682382     0.118072
#
#      electrocardiographic   heart rate  exercise induced  depression
# sex
# 0                 0.657303  147.700565          0.209040     0.659551  \
# 1                 0.590909  143.085919          0.360382     0.882816
#
#         slope        ca      thal         c
# sex
# 0    1.609756  0.632653  3.815534  0.207865
# 1    1.704225  0.721951  5.265487  0.496420

# %%
df.groupby('sex')[['blood sugar']].mean()
# Out:
#      blood sugar
# sex
# 0       0.091954
# 1       0.118072

# %%
df.groupby(['sex'],sort=False)[['blood sugar']].mean()
# Out:
#      blood sugar
# sex
# 1       0.118072
# 0       0.091954

# %% [markdown]
# # Data Frame Filtering

# %%
df_sub= df[df['Age (age in year)']< 40]
df_sub
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral
# 1                   37    1           3           130.0         250.0  \
# 44                  39    1           3           140.0         321.0
# 58                  34    1           1           118.0         182.0
# 65                  35    0           4           138.0         183.0
# 72                  29    1           2           130.0         204.0
# ..                 ...  ...         ...             ...           ...
# 483                 32    1           4           118.0         529.0
# 492                 38    1           4           110.0           NaN
# 495                 39    1           4           110.0         280.0
# 517                 39    1           4           118.0         219.0
# 579                 38    1           1           120.0         231.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced
# ...

# %%
df_f = df[df["sex"]==0]
df_f.shape
# Out:
# (178, 14)

# %%
df[['sex','cholestoral ']]
# Out:
#      sex  cholestoral
# 0      1         233.0
# 1      1         250.0
# 2      0         204.0
# 3      1         236.0
# 4      0         354.0
# ..   ...           ...
# 592    1         266.0
# 593    1         288.0
# 594    1         336.0
# 595    1         491.0
# 596    1         222.0
#
# [597 rows x 2 columns]

# %%
df[10:20]
# Out:
#     Age (age in year)  sex  chest pain  blood pressure  cholestoral
# 10                 54    1           4           140.0         239.0  \
# 11                 48    0           3           130.0         275.0
# 12                 49    1           2           130.0         266.0
# 13                 64    1           1           110.0         211.0
# 14                 58    0           1           150.0         283.0
# 15                 50    0           3           120.0         219.0
# 16                 58    0           3           120.0         340.0
# 17                 66    0           1           150.0         226.0
# 18                 43    1           4           150.0         247.0
# 19                 69    0           1           140.0         239.0
#
#     blood sugar  electrocardiographic   heart rate  exercise induced
# 10          0.0                    0.0       160.0               0.0  \
# ...

# %% [markdown]
# # Method loc,iloc

# %%
df.loc[10:20, ["sex","blood pressure","blood sugar"]]
# Out:
#     sex  blood pressure  blood sugar
# 10    1           140.0          0.0
# 11    0           130.0          0.0
# 12    1           130.0          0.0
# 13    1           110.0          0.0
# 14    0           150.0          1.0
# 15    0           120.0          0.0
# 16    0           120.0          0.0
# 17    0           150.0          0.0
# 18    1           150.0          0.0
# 19    0           140.0          0.0
# 20    1           135.0          0.0

# %%
df.iloc[10:20, [0,3,4,5]]
# Out:
#     Age (age in year)  blood pressure  cholestoral   blood sugar
# 10                 54           140.0         239.0          0.0
# 11                 48           130.0         275.0          0.0
# 12                 49           130.0         266.0          0.0
# 13                 64           110.0         211.0          0.0
# 14                 58           150.0         283.0          1.0
# 15                 50           120.0         219.0          0.0
# 16                 58           120.0         340.0          0.0
# 17                 66           150.0         226.0          0.0
# 18                 43           150.0         247.0          0.0
# 19                 69           140.0         239.0          0.0

# %%
df.iloc[0]
df.iloc[-1]
# Out:
# Age (age in year)         49.0
# sex                        1.0
# chest pain                 4.0
# blood pressure           150.0
# cholestoral              222.0
# blood sugar                0.0
# electrocardiographic       0.0
# heart rate               122.0
# exercise induced           0.0
# depression                 2.0
# slope                      2.0
# ca                         NaN
# thal                       NaN
# c                          1.0
# Name: 596, dtype: float64

# %%
df.iloc[:,0]
df.iloc[:,-1]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 592    1
# 593    1
# 594    1
# 595    1
# 596    1
# Name: c, Length: 597, dtype: int64

# %% [markdown]
# # Data Frame: Sorting

# %%
df_sorted = df.sort_values(by = "Age (age in year)")
df_sorted
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral
# 299                 28    1           2           130.0         132.0  \
# 72                  29    1           2           130.0         204.0
# 271                 29    1           2           120.0         243.0
# 305                 29    1           2           140.0           NaN
# 302                 30    0           1           170.0         237.0
# ..                 ...  ...         ...             ...           ...
# 60                  71    0           3           110.0         265.0
# 25                  71    0           2           160.0         302.0
# 129                 74    0           2           120.0         269.0
# 144                 76    0           3           140.0         197.0
# 577                 77    1           4           125.0         304.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced
# ...

# %%
df_sorted.head()
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral
# 299                 28    1           2           130.0         132.0  \
# 72                  29    1           2           130.0         204.0
# 271                 29    1           2           120.0         243.0
# 305                 29    1           2           140.0           NaN
# 302                 30    0           1           170.0         237.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced
# 299          0.0                    2.0       185.0               0.0  \
# 72           0.0                    2.0       202.0               0.0
# 271          0.0                    0.0       160.0               0.0
# 305          0.0                    0.0       170.0               0.0
# 302          0.0                    1.0       170.0               0.0
#
#      depression   slope   ca  thal  c
# 299          0.0    NaN  NaN   NaN  0
# 72           0.0    1.0  0.0   3.0  0
# ...

# %%
df.sort_values(by=["sex", 'Age (age in year)'], ascending=[False,True])
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral
# 299                 28    1           2           130.0         132.0  \
# 72                  29    1           2           130.0         204.0
# 271                 29    1           2           120.0         243.0
# 305                 29    1           2           140.0           NaN
# 415                 31    1           4           120.0         270.0
# ..                 ...  ...         ...             ...           ...
# 25                  71    0           2           160.0         302.0
# 60                  71    0           3           110.0         265.0
# 151                 71    0           4           112.0         149.0
# 129                 74    0           2           120.0         269.0
# 144                 76    0           3           140.0         197.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced
# ...

# %% [markdown]
# # Missing Values

# %%
df[df.isnull().any(axis=1)].shape
# Out:
# (299, 14)

# %%
df2.dropna().shape
# Out:
# (298, 14)

# %%
df3 = df
#Drop Rows where all cells is NA
df3.dropna(how="all").shape
# Out:
# (597, 14)

# %%
df3.dropna(thresh=6).shape
# Out:
# (597, 14)

# %%
df3.isnull().sum()
# Out:
# Age (age in year)          0
# sex                        0
# chest pain                 0
# blood pressure             1
# cholestoral               23
# blood sugar                8
# electrocardiographic       1
# heart rate                 1
# exercise induced           1
# depression                 0
# slope                    190
# ca                       294
# thal                     268
# c                          0
# dtype: int64

# %%
df3.notnull().sum()/597 *100
# Out:
# Age (age in year)        100.000000
# sex                      100.000000
# chest pain               100.000000
# blood pressure            99.832496
# cholestoral               96.147404
# blood sugar               98.659966
# electrocardiographic      99.832496
# heart rate                99.832496
# exercise induced          99.832496
# depression               100.000000
# slope                     68.174204
# ca                        50.753769
# thal                      55.108878
# c                        100.000000
# dtype: float64

# %%
df_cum= df['slope'].cumsum()
df_cum
# Out:
# 0        3.0
# 1        6.0
# 2        7.0
# 3        8.0
# 4        9.0
#        ...
# 592    676.0
# 593    678.0
# 594    680.0
# 595      NaN
# 596    682.0
# Name: slope, Length: 597, dtype: float64

# %% [markdown]
# # Aggregation functions in pandas

# %%
df[["blood sugar","Age (age in year)"]].agg(["min","max","mean"],axis=0)
# Out:
#       blood sugar  Age (age in year)
# min      0.000000           28.00000
# max      1.000000           77.00000
# mean     0.110357           51.18258

# %% [markdown]
# # Descriptive Statistics

# %%
df["Age (age in year)"].skew()
# Out:
# -0.05720393335880286

# %%
df["Age (age in year)"].kurt()
# Out:
# -0.4077140105911945

# %%
df.describe().T
# Out:
#                        count        mean        std   min    25%    50%
# Age (age in year)      597.0   51.182580   9.074366  28.0   44.0   52.0  \
# sex                    597.0    0.701843   0.457833   0.0    0.0    1.0
# chest pain             597.0    3.072027   0.965776   1.0    2.0    3.0
# blood pressure         596.0  132.129195  17.603812  92.0  120.0  130.0
# cholestoral            574.0  248.655052  59.784805  85.0  211.0  242.5
# blood sugar            589.0    0.110357   0.313600   0.0    0.0    0.0
# electrocardiographic   596.0    0.610738   0.869358   0.0    0.0    0.0
# heart rate             596.0  144.456376  23.794282  71.0  128.0  146.0
# exercise induced       596.0    0.315436   0.465080   0.0    0.0    0.0
# depression             597.0    0.816248   1.067938   0.0    0.0    0.2
# slope                  407.0    1.675676   0.572758   1.0    1.0    2.0
# ca                     303.0    0.693069   1.049212   0.0    0.0    0.0
# ...

# %%
df["Age (age in year)"].std()
# Out:
# 9.074366399338714

# %% [markdown]
# # Graphics to explore the data

# %%
df.hist(figsize=(18,12))
plt.show()

# %%
# %matplotlib inline

# %%
list1=['Age (age in year)']
for i in df[list1]:    
    plt.violinplot(df[i],vert=False)
    plt.show()
